# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd

df = pd.read_excel("data/Hr_data.xlsx")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel("data/Hr_data.xlsx")
#       4
#       5 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 5.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.5 MB 3.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.5 MB 3.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.5 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.5 MB 3.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.5 MB 3.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.5 MB 3.4 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.5 MB 3.4 MB/s eta 0:00:02
#    --------------------------- ------------ 6.6/9.5 MB 3.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.5 MB 3.5 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.5 MB 3.4 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\HP

# %%
print(os.listdir())
# Out:
# ['.copilot', '.fop', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.ms-ad', '.pdfbox.cache', '.vscode', '3D Objects', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'Music', 'My Documents', 'MyPython', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'project', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Sti_Trace.log', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Videos']

# %%
import os

print(os.listdir("Downloads"))
# Out:
# ['00XXXXX592_01-09-2025_28-12-2025 (1).pdf', '00XXXXX592_01-09-2025_28-12-2025.pdf', 'APRIL 2026 (1).pdf', 'archive', 'archive (1).zip', 'archive.zip', 'com.gov.ssc_2.4.7.xapk', 'Configuration.xml', 'css notes (1).pdf', 'css notes.pdf', 'CV SAKSHI.docx', 'CV SAKSHI.pdf', 'Dashboard.jpg.jpg', 'desktop.ini', 'FEB.pdf', 'Geography One Day - 2026 (1).pdf', 'GitHubDesktopSetup-x64 (1).exe', 'GitHubDesktopSetup-x64.exe', 'Gray and White Simple Professional Marketing Manager CV Resume (1).pdf', 'Gray and White Simple Professional Marketing Manager CV Resume.pdf', 'Hr Data.xlsx', 'HTMLLA (1).pdf', 'image.jpg', 'IMG (2).pdf', 'img.jpg', 'IMG_2539.JPG', 'IMG_2580.JPG', 'JAN.pdf', 'JS Notes (1).pdf', 'ldplayer_downloader.exe', 'MARCH.pdf', 'MAY 2026.pdf', 'Microsoft.Services.Store.winmd', 'MPSC_ Online Application System.html', 'MPSC_ Online Application System_files', 'node-v24.12.0-x64.msi', 'officedeploymenttool_20026-20112.exe', 'one day economics.pdf', 'pan card.jpeg', 'pancard_20260129_161
# ...

# %%
df = pd.read_excel("Downloads/Hr_data.xlsx")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_excel("Downloads/Hr_data.xlsx")
#       2
#       3 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
# ...

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\HP\Downloads\Hr_data.xlsx")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_excel(r"C:\Users\HP\Downloads\Hr_data.xlsx")
#       4
#       5 df.head()
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
import os

print(os.listdir(r"C:\Users\HP\Downloads"))
# Out:
# ['00XXXXX592_01-09-2025_28-12-2025 (1).pdf', '00XXXXX592_01-09-2025_28-12-2025.pdf', 'APRIL 2026 (1).pdf', 'archive', 'archive (1).zip', 'archive.zip', 'com.gov.ssc_2.4.7.xapk', 'Configuration.xml', 'css notes (1).pdf', 'css notes.pdf', 'CV SAKSHI.docx', 'CV SAKSHI.pdf', 'Dashboard.jpg.jpg', 'desktop.ini', 'FEB.pdf', 'Geography One Day - 2026 (1).pdf', 'GitHubDesktopSetup-x64 (1).exe', 'GitHubDesktopSetup-x64.exe', 'Gray and White Simple Professional Marketing Manager CV Resume (1).pdf', 'Gray and White Simple Professional Marketing Manager CV Resume.pdf', 'Hr Data.xlsx', 'HTMLLA (1).pdf', 'image.jpg', 'IMG (2).pdf', 'img.jpg', 'IMG_2539.JPG', 'IMG_2580.JPG', 'JAN.pdf', 'JS Notes (1).pdf', 'ldplayer_downloader.exe', 'MARCH.pdf', 'MAY 2026.pdf', 'Microsoft.Services.Store.winmd', 'MPSC_ Online Application System.html', 'MPSC_ Online Application System_files', 'node-v24.12.0-x64.msi', 'officedeploymenttool_20026-20112.exe', 'one day economics.pdf', 'pan card.jpeg', 'pancard_20260129_161
# ...

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\HP\Downloads\Hr Data.xlsx")

df.head()
# Out:
#   Employee ID   Employee Name Department  Gender  Age  Salary Attrition  \
# 0      EMP001     Rahul Patil         IT    Male   24   45000        No
# 1      EMP002     Sneha Joshi         HR  Female   29   52000       Yes
# 2      EMP003     Amit Sharma      Sales    Male   31   60000        No
# 3      EMP004  Priya Kulkarni    Finance  Female   27   55000        No
# 4      EMP005     Rohit Verma         IT    Male   26   68000       Yes
#
#             Job Role  Experience       City
# 0       Data Analyst           2       Pune
# 1       HR Executive           5     Mumbai
# 2    Sales Executive           7      Delhi
# 3         Accountant           4     Nagpur
# 4  Software Engineer           3  Bangalore

# %%
df.shape
# Out:
# (120, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee ID    120 non-null    str
#  1   Employee Name  120 non-null    str
#  2   Department     120 non-null    str
#  3   Gender         120 non-null    str
#  4   Age            120 non-null    int64
#  5   Salary         120 non-null    int64
#  6   Attrition      120 non-null    str
#  7   Job Role       120 non-null    str
#  8   Experience     120 non-null    int64
#  9   City           120 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 9.5 KB

# %%
df.isnull().sum()
# Out:
# Employee ID      0
# Employee Name    0
# Department       0
# Gender           0
# Age              0
# Salary           0
# Attrition        0
# Job Role         0
# Experience       0
# City             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Department"].value_counts()
# Out:
# Department
# IT           36
# HR           25
# Sales        23
# Finance      20
# Marketing    16
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      61
# Female    59
# Name: count, dtype: int64

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     95
# Yes    25
# Name: count, dtype: int64

# %%
attrition_rate = (df["Attrition"] == "Yes").mean() * 100

print("Attrition Rate:", round(attrition_rate, 2), "%")
# Out:
# Attrition Rate: 20.83 %

# %%
df["Salary"].mean()
# Out:
# np.float64(61408.333333333336)

# %%
df.groupby("Department")["Salary"].mean().round(2)
# Out:
# Department
# Finance      65650.00
# HR           50200.00
# IT           70611.11
# Marketing    50687.50
# Sales        62956.52
# Name: Salary, dtype: float64

# %%
df["Experience"].mean()
# Out:
# np.float64(5.6)

# %%
df.groupby("Department")["Experience"].mean().round(2)
# Out:
# Department
# Finance      6.90
# HR           4.32
# IT           5.47
# Marketing    4.12
# Sales        7.09
# Name: Experience, dtype: float64

# %%
import matplotlib.pyplot as plt

df["Department"].value_counts().plot(kind="bar")

plt.title("Employees by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.xticks(rotation=0)
plt.show()

# %%
df["Gender"].value_counts().plot(kind="pie", autopct="%1.1f%%")

plt.title("Employee Distribution by Gender")
plt.ylabel("")
plt.show()

# %%
df["Attrition"].value_counts().plot(kind="bar")

plt.title("Employee Attrition")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")
plt.xticks(rotation=0)
plt.show()
